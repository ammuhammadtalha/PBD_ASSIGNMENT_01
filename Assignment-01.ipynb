# %%
import pandas as pd
import numpy as np
df = pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df.head(20)
# Out:
#         study_id  subtlety  size age  gender       x       y      state  \
# 0   JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1   JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2   JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3   JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4   JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5   JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6   JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7   JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8   JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9   JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
# 10  JPCLN011.png       5.0  20.0  68    Male   647.0   401.0     benign
# 11  JPCLN012.png       5.0  37.0  80    Male   268.0  1136.0  malignant
# ...

# %% [markdown]
# # Task No.01#Find the total number of patients of each disease (diagnosis) and plot in histogram.

# %%
df.isnull()
# Out:
#      study_id  subtlety   size    age  gender      x      y  state  position  \
# 0       False     False  False  False   False  False  False  False     False
# 1       False     False  False  False   False  False  False  False     False
# 2       False     False  False  False   False  False  False  False     False
# 3       False     False  False  False   False  False  False  False     False
# 4       False     False  False  False   False  False  False  False     False
# ..        ...       ...    ...    ...     ...    ...    ...    ...       ...
# 242     False      True   True  False   False   True   True  False      True
# 243     False      True   True  False   False   True   True  False      True
# 244     False      True   True  False   False   True   True  False      True
# 245     False      True   True  False   False   True   True  False      True
# 246     False      True   True  False   False   True   True  False      True
#
#      diagnosis
# 0        False
# ...

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['subtlety'].head()
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: subtlety, dtype: float64

# %%
m = df['subtlety'].astype('float').mean()

# %%
 df['subtlety'].replace(np.nan,m,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['size'].head()
# Out:
# 0    15.0
# 1    30.0
# 2    30.0
# 3    14.0
# 4    35.0
# Name: size, dtype: float64

# %%
m = df['size'].astype('float').mean()

# %%
df['size'].replace(np.nan,m,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['x'].head()
# Out:
# 0    1634.0
# 1    1614.0
# 2    1303.0
# 3     606.0
# 4    1438.0
# Name: x, dtype: float64

# %%
m = df['x'].astype('float').mean()

# %%
df['x'].replace(np.nan,m,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['y'].head()
# Out:
# 0     692.0
# 1    1090.0
# 2     447.0
# 3     836.0
# 4     692.0
# Name: y, dtype: float64

# %%
m = df['y'].astype('float').mean()

# %%
df['y'].replace(np.nan,m,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y             0
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['position'].head()
# Out:
# 0          l.upper lobe
# 1      l.upper lobe(S5)
# 2    l.upper lobe(S1+2)
# 3          r.upper lobe
# 4      l.upper lobe(S3)
# Name: position, dtype: object

# %%
mx = df['position'].value_counts()

# %%
mx
# Out:
# r.upper lobe(S2)       16
# r.upper lobe(S1)       15
# r.upper lobe           13
# r.lower lobe(S6)       10
# left lung               9
# l.upper lobe(S1+2)      8
# l.upper lobe            7
# r.middle lobe(S4)       7
# r.upper lobe(S3)        7
# l.lower lobe(S6)        6
# r.lower lobe            6
# l.lower lobe(S10)       6
# l.lower lobe            6
# l.upper lobe(S3)        6
# r.middle lobe           5
# l.upper lobe(S4)        5
# r.lower lobe(S10)       3
# right lung              3
# r.lower lobe(S9)        3
# l.upper lobe(S5)        2
# r.lower lobe(S8)        2
# r.lower lobe(S7)        2
# l.lower lobe(S8)        2
# r.upper lobe(S2-S3)     1
# r.lower lobe(S9-10)     1
# r.middle lobe(S5)       1
# l.lower lobe(S9)        1
# l.lower lobe(S6-S8)     1
# Name: position, dtype: int64

# %%
mx = df['position'].value_counts().idxmax()

# %%
mx
# Out:
# 'r.upper lobe(S2)'

# %%
df['position'].replace(np.nan,mx,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y             0
# state         0
# position      0
# diagnosis    93
# dtype: int64

# %%
mx = df['diagnosis'].value_counts().idxmax()

# %%
mx
# Out:
# 'lung cancer'

# %%
df['diagnosis'].replace(np.nan,mx,inplace = True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.title('Diagnosis')
plt.pyplot.ylabel('No of Patients')
plt.pyplot.xlabel('Disease')
plt.pyplot.hist(df['diagnosis'],color = 'brown',ec = 'black',bins = 20)
# Out:
# (array([151.,  16.,   8.,  25.,   4.,   9.,   2.,   3.,   3.,   5.,   5.,
#           2.,   2.,   1.,   2.,   1.,   3.,   1.,   2.,   2.]),
#  array([ 0.  ,  1.55,  3.1 ,  4.65,  6.2 ,  7.75,  9.3 , 10.85, 12.4 ,
#         13.95, 15.5 , 17.05, 18.6 , 20.15, 21.7 , 23.25, 24.8 , 26.35,
#         27.9 , 29.45, 31.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # Task No# 02 Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in a pie chart

# %%
df[['diagnosis','state']].value_counts()
# Out:
# diagnosis                                       state
# lung cancer                                     non-nodule    93
#                                                 malignant     56
# lung cancer(adenocarcinoma)                     malignant     23
# tuberculoma                                     benign        14
# granuloma                                       benign         8
# lung cancer(bronchioloalveolar cell carcinoma)  malignant      7
# metastasis of colon cancer                      malignant      4
# unknown                                         benign         4
# inflammatory mass                               benign         4
# pulmonary tuberculosis                          benign         3
# lung abscess                                    benign         2
# Inflammatory mass                               benign         2
# susp. inflammatory mass                         benign         2
# sclerosing hemangioma                           benign         2
# ...

# %%
w=['lung cancer','lung cancer(adenocarcinoma)','tuberculoma','granuloma',
   'lung cancer(bronchioloalveolar cell carcinoma)','unknown','metastasis of colon cancer',
   'inflammatory mass','pulmonary tuberculosis','lung abscess','Cryptococcosis','lung cancer(squamous cell carcinoma)'
   ,'Inflammatory mass','pulmonary hematoma','susp. inflammatory mass','hamartoma','sclerosing hemangioma','lung cancer(large cell carcinoma)','susp. hamartoma','metastasis of uterine cancer','organizing pneumonia','metastasis of ovarian cancer','metastatic lung cancer','lung canceror metastasis','pneumonia','calcified granuloma','lung cancer(adenosquamous carcinoma)','lung cancer(small cell carcinoma)','susp.tuberculoma','organiging pneumonia','susp. sclerosing hemangioma','susp. lung metastasis']
plt.pyplot.pie(df["diagnosis"].value_counts(),labels=w,startangle = 35)
# Out:
# ([<matplotlib.patches.Wedge at 0x27598793a00>,
# ...
#  [Text(-0.8851894431668369, 0.653023467959602, 'lung cancer'),
#   Text(-0.020596411110840117, -1.0998071593917516, 'lung cancer(adenocarcinoma)'),
#   Text(0.48032122893739376, -0.9895915910273652, 'tuberculoma'),
#   Text(0.7349455857544068, -0.8184466909824439, 'granuloma'),
#   Text(0.8768122925956128, -0.6642290294418227, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(0.9608734141719303, -0.5354645477877862, 'unknown'),
#   Text(1.0102941337051714, -0.43509282159203405, 'metastasis of colon cancer'),
#   Text(1.0492638272156072, -0.3302202611846472, 'inflammatory mass'),
#   Text(1.0744695537333329, -0.23561659130904294, 'pulmonary tuberculosis'),
#   Text(1.0872714726084531, -0.16685546095901682, 'lung abscess'),
#   Text(1.094349923433473, -0.11134740715953739, 'Cryptococcosis'),
#   Text(1.0985964060277758, -0.05555120757332532, 'lung cancer(squamous cell carcinoma)'),
# ...

# %%
df['state'].value_counts()
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
test=df.groupby(by=["diagnosis"])

# %%
a=test.get_group('lung cancer')

# %%
plt.pyplot.title(" Lung Cancer ")
plt.pyplot.pie(a['state'].value_counts(),labels=['malignant','beginin'],shadow = True,colors = ['cyan','purple','blue']
              ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x15fbecaa040>,
# ...
#  [Text(-0.9261696565076241, 0.5934726340485716, 'malignant'),
#   Text(1.0103668980083176, -0.6474246916893501, 'beginin')],
#  [Text(-0.5051834490041585, 0.3237123458446754, '62.416%'),
#   Text(0.589380690504852, -0.37766440348545416, '37.584%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(adenocarcinoma)')
plt.pyplot.title(" lung cancer(adenocarcinoma) ")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x15fbed33130>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('tuberculoma')
plt.pyplot.title("Tuberculoma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x15fbed7c310>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('granuloma')
plt.pyplot.title("Granuloma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x15fbedc43d0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(bronchioloalveolar cell carcinoma)')
plt.pyplot.title("Lung Cancer(bronchioloalveolar cell carcinoma)")
plt.pyplot.pie(a['state'].value_counts(),labels=['malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x15fbee0e3a0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('metastasis of colon cancer')
plt.pyplot.title("Metastasis of Colon Cancer")
plt.pyplot.pie(a['state'].value_counts(),labels=['malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ea7e610>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('unknown')
plt.pyplot.title("Unknown")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ebfa160>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('inflammatory mass')
plt.pyplot.title("Inflammatory Mass")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ecb1430>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('pulmonary tuberculosis')
plt.pyplot.title("Pulmonary Tuberculosis")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ecfd2e0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung abscess')
plt.pyplot.title("Lung Abscess")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ed43400>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('Inflammatory mass')
plt.pyplot.title("Inflammatory Mass")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ed8c490>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('susp. inflammatory mass')
plt.pyplot.title("Susp. Inflammatory Mass")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6edd4490>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('sclerosing hemangioma')
plt.pyplot.title("Sclerosing Hemangioma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ee64550>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('pulmonary hematoma')
plt.pyplot.title("Pulmonary Hematoma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6eeaa6a0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('Cryptococcosis')
plt.pyplot.title("Cryptococcosis")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6eef57c0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('hamartoma')
plt.pyplot.title("Hamartoma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ef3e670>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(squamous cell carcinoma)')
plt.pyplot.title("Lung Cancer(squamous cell carcinoma)")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6ef85700>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung canceror metastasis')
plt.pyplot.title("Lung Canceror Metastasis")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6efcf880>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('calcified granuloma')
plt.pyplot.title("Calcified Granuloma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6f017880>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('susp.tuberculoma')
plt.pyplot.title("Susp.Tuberculoma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f6f060940>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('susp. sclerosing hemangioma')
plt.pyplot.title("Susp. Sclerosing Hemangioma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f700bab20>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('susp. lung metastasis')
plt.pyplot.title("Susp. Lung Metastasis")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70103b80>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(adenosquamous carcinoma)')
plt.pyplot.title("Lung Cancer(adenosquamous carcinoma)")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7014ac10>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('susp. hamartoma')
plt.pyplot.title("Susp. Hamartoma")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70223d90>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(large cell carcinoma)')
plt.pyplot.title("Lung Cancer(large cell carcinoma)")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f702b5eb0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('metastasis of ovarian cancer')
plt.pyplot.title("Metastasis of Ovarian Cancer")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f702ffee0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(small cell carcinoma)')
plt.pyplot.title("Lung Cancer(small cell carcinoma)")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70347ee0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('pneumonia')
plt.pyplot.title("Pneumonia")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7038ef40>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('organizing pneumonia')
plt.pyplot.title("Organizing Pneumonia")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f703d8f40>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('metastatic lung cancer')
plt.pyplot.title("Metastatic Lung Cancer")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7042d040>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('metastasis of uterine cancer')
plt.pyplot.title("Metastasis of Uterine Cancer")
plt.pyplot.pie(a['state'].value_counts(),labels=['Malignant'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70476100>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Malignant')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('organiging pneumonia')
plt.pyplot.title("Organiging Pneumonia")
plt.pyplot.pie(a['state'].value_counts(),labels=['Benign'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f704c01c0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Benign')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %% [markdown]
# # Task No 03: - Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender(Female,Male)

# %%
df[['diagnosis','gender']].value_counts()
# Out:
# diagnosis                                       gender
# lung cancer                                     Male      75
#                                                 Female    74
# lung cancer(adenocarcinoma)                     Female    15
# tuberculoma                                     Male       9
# lung cancer(adenocarcinoma)                     Male       8
# granuloma                                       Male       6
# tuberculoma                                     Female     5
# unknown                                         Female     4
# lung cancer(bronchioloalveolar cell carcinoma)  Female     4
# pulmonary tuberculosis                          Male       3
# lung cancer(bronchioloalveolar cell carcinoma)  Male       3
# metastasis of colon cancer                      Female     3
# Cryptococcosis                                  Female     2
# hamartoma                                       Female     2
# ...

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer')
plt.pyplot.title(" Lung Cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.5],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f705abd90>,
# ...
#  [Text(-0.6403980622519944, 0.8943658769563443, 'Male'),
#   Text(0.9314879687496949, -1.300895908239613, 'Female')],
#  [Text(-0.34930803395563326, 0.48783593288527866, '50.336%'),
#   Text(0.6403979785154151, -0.8943659369147339, '49.664%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('lung cancer(adenocarcinoma)')
plt.pyplot.title(" Lung Cancer(adenocarcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f705e0fa0>,
# ...
#  [Text(-0.974746618538402, 0.5097735081856952, 'Male'),
#   Text(1.063359999563824, -0.5561164548254476, 'Female')],
#  [Text(-0.5316799737482192, 0.27805827719219733, '65.217%'),
#   Text(0.6202933330788973, -0.3244012653148444, '34.783%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group('tuberculoma')
plt.pyplot.title("Tuberculoma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f706938b0>,
# ...
#  [Text(-0.9594103764423152, 0.5380815268849277, 'Male'),
#   Text(1.046629501573435, -0.5869980293290114, 'Female')],
#  [Text(-0.5233147507867173, 0.293499014664506, '64.286%'),
#   Text(0.6105338759178371, -0.34241551710858986, '35.714%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(adenocarcinoma)")
plt.pyplot.title("Lung Cancer(adenocarcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f706ee340>,
# ...
#  [Text(-0.974746618538402, 0.5097735081856952, 'Male'),
#   Text(1.063359999563824, -0.5561164548254476, 'Female')],
#  [Text(-0.5316799737482192, 0.27805827719219733, '65.217%'),
#   Text(0.6202933330788973, -0.3244012653148444, '34.783%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("granuloma")
plt.pyplot.title("Granuloma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70732c70>,
# ...
#  [Text(-1.0832885283134288, 0.19101299543362377, 'Male'),
#   Text(1.1817693036146497, -0.20837781320031648, 'Female')],
#  [Text(-0.5908846518073247, 0.1041889066001584, '75.000%'),
#   Text(0.6893654271085455, -0.12155372436685127, '25.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("tuberculoma")
plt.pyplot.title("Tuberculoma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7078a7f0>,
# ...
#  [Text(-0.9594103764423152, 0.5380815268849277, 'Male'),
#   Text(1.046629501573435, -0.5869980293290114, 'Female')],
#  [Text(-0.5233147507867173, 0.293499014664506, '64.286%'),
#   Text(0.6105338759178371, -0.34241551710858986, '35.714%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("unknown")
plt.pyplot.title("Unknown")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7082dd90>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(bronchioloalveolar cell carcinoma)")
plt.pyplot.title("Lung Cancer(bronchioloalveolar cell carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f70930970>,
# ...
#  [Text(-0.8156216302994039, 0.7380795053297055, 'Male'),
#   Text(0.8897691266218815, -0.8051775588716655, 'Female')],
#  [Text(-0.44488452561785663, 0.4025888210889302, '57.143%'),
#   Text(0.5190319905294308, -0.4696869093418049, '42.857%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("pulmonary tuberculosis")
plt.pyplot.title("Pulmonary Tuberculosis")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f719b5130>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(bronchioloalveolar cell carcinoma)")
plt.pyplot.title("Lung Cancer(bronchioloalveolar cell carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f719fc310>,
# ...
#  [Text(-0.8156216302994039, 0.7380795053297055, 'Male'),
#   Text(0.8897691266218815, -0.8051775588716655, 'Female')],
#  [Text(-0.44488452561785663, 0.4025888210889302, '57.143%'),
#   Text(0.5190319905294308, -0.4696869093418049, '42.857%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("metastasis of colon cancer")
plt.pyplot.title("Metastasis of Colon Cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71a43d30>,
# ...
#  [Text(-1.0832885283134288, 0.19101299543362377, 'Male'),
#   Text(1.1817693036146497, -0.20837781320031648, 'Female')],
#  [Text(-0.5908846518073247, 0.1041889066001584, '75.000%'),
#   Text(0.6893654271085455, -0.12155372436685127, '25.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("Cryptococcosis")
plt.pyplot.title("Cryptococcosis")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71afa3d0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("hamartoma")
plt.pyplot.title("Hamartoma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71b3c6a0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("inflammatory mass")
plt.pyplot.title("Inflammatory Mass")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71be8340>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("granuloma")
plt.pyplot.title("Granuloma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71c2ceb0>,
# ...
#  [Text(-1.0832885283134288, 0.19101299543362377, 'Male'),
#   Text(1.1817693036146497, -0.20837781320031648, 'Female')],
#  [Text(-0.5908846518073247, 0.1041889066001584, '75.000%'),
#   Text(0.6893654271085455, -0.12155372436685127, '25.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("sclerosing hemangioma")
plt.pyplot.title("Sclerosing Hemangioma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71ce2490>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(squamous cell carcinoma)")
plt.pyplot.title("Lung Cancer(squamous cell carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71d26760>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("Inflammatory mass")
plt.pyplot.title("Inflammatory Mass")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71a43af0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp. inflammatory mass")
plt.pyplot.title("Susp. Inflammatory Mass")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f707eb670>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp. hamartoma")
plt.pyplot.title("Susp. Hamartoma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f707af8b0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp. inflammatory mass")
plt.pyplot.title("Susp. Inflammatory Mass")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7087cb80>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp. sclerosing hemangioma")
plt.pyplot.title("Susp. Sclerosing Hemangioma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71ddb370>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp. lung metastasis")
plt.pyplot.title("Susp. Lung Metastasis")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71e22640>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("pulmonary hematoma")
plt.pyplot.title("Pulmonary Hematoma ")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71eca1f0>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("susp.tuberculoma")
plt.pyplot.title("Susp.Tuberculoma ")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71f6b970>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("calcified granuloma")
plt.pyplot.title("Calcified Granuloma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71fb1d00>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("pulmonary hematoma")
plt.pyplot.title("Pulmonary hematoma")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f72056910>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung abscess")
plt.pyplot.title("Lung Abscess")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f720b0430>,
# ...
#  [Text(-0.6309340799861505, 0.9010672487178913, 'Male'),
#   Text(0.6882917236212553, -0.9829824531467902, 'Female')],
#  [Text(-0.3441458618106275, 0.49149122657339517, '50.000%'),
#   Text(0.4015035054457322, -0.5734064310022943, '50.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("pneumonia")
plt.pyplot.title("Pneumonia")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f721529a0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("organiging pneumonia")
plt.pyplot.title("Organiging Pneumonia")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f721e3d00>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("metastatic lung cancer")
plt.pyplot.title("Metastatic Lung Cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7222ccd0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("metastasis of uterine cancer")
plt.pyplot.title("metastasis of uterine cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f72276d60>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("metastasis of ovarian cancer")
plt.pyplot.title("metastasis of ovarian cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f722bedf0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("metastasis of colon cancer")
plt.pyplot.title("metastasis of colon cancer")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male','Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0,0.1],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f7332fa30>,
# ...
#  [Text(-1.0832885283134288, 0.19101299543362377, 'Male'),
#   Text(1.1817693036146497, -0.20837781320031648, 'Female')],
#  [Text(-0.5908846518073247, 0.1041889066001584, '75.000%'),
#   Text(0.6893654271085455, -0.12155372436685127, '25.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung canceror metastasis")
plt.pyplot.title("lung canceror metastasis")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Female'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f722dadc0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Female')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(small cell carcinoma)")
plt.pyplot.title("lung cancer(small cell carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f720cb940>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(large cell carcinoma)")
plt.pyplot.title("Lung Cancer(large cell carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71f798e0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])

# %%
test=df.groupby(by=["diagnosis"])
a=test.get_group("lung cancer(adenosquamous carcinoma)")
plt.pyplot.title("lung cancer(adenosquamous carcinoma)")
plt.pyplot.pie(a['gender'].value_counts(),labels=['Male'],shadow = True,colors = ['cyan','purple','blue']
               ,explode = [0],autopct ='%1.3f%%',startangle = 35 )
# Out:
# ([<matplotlib.patches.Wedge at 0x22f71f0f1c0>],
#  [Text(-0.9010672487178907, -0.6309340799861511, 'Male')],
#  [Text(-0.49149122657339483, -0.3441458618106279, '100.000%')])
